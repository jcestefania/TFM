# %%
import os
# Asegurar que el notebook se ejecuta desde la raíz del proyecto para que las rutas relativas coincidan
if os.path.basename(os.getcwd()) == 'examples':
    os.chdir('..')
print(f"Directorio actual: {os.getcwd()}")
# Out:
# Directorio actual: c:\Users\juanc\Desktop\TFM\TFM-Juan Carlos\Software\SAREnv

# %% [markdown]
# # SAREnv: Pruebas Rápidas - Entorno Casa de Campo
#
# Este notebook permite ejecutar de forma secuencial y rápida las simulaciones de Búsqueda y Rescate (SAR) en el entorno de la Casa de Campo.
#
# **Objetivo de Integración:**
# Actualmente llamamos a los algoritmos "baseline" del entorno (Greedy, Spiral, Lawnmower, etc.). La arquitectura del software está preparada para que, en el futuro, nuestros sistemas de planificación propios se integren como una nueva clase bajo `sarenv/core/planners` (o similar) y puedan ser importados y evaluados exactamente con este mismo pipeline.

# %% [markdown]
# ## 1. Generación del Mapa y Probabilidades
# Primero generamos el mapa base de la Casa de Campo (si no está cacheado), descargando los datos de OpenStreetMap y generando la matriz de probabilidades (Heatmap).

# %%
import os

# Comprobamos si la carpeta ya existe para no repetir la generación pesada (30 mins)
if not os.path.exists("resultados_casa_de_campo"):
    print("Generando mapa desde cero... Esto puede tardar bastante.")
    from examples.generar_casa_de_campo import generar_casa_de_campo
    generar_casa_de_campo()
    print("✅ Mapa de Casa de Campo y probabilidades listos.")
else:
    print("⏭️ El mapa de Casa de Campo YA ESTÁ GENERADO en disco. Pasando al siguiente paso...")
# Out:
# ⏭️ El mapa de Casa de Campo YA ESTÁ GENERADO en disco. Pasando al siguiente paso...

# %% [markdown]
# ## 1.1 Generación de Entorno por Punto LKP
# Generamos también el entorno a partir de un único punto central (PLS - Point Last Seen).

# %%
import os

# Al igual que antes, comprobamos si el mapa radial ya está descargado en disco
if not os.path.exists("resultados_casa_de_campo_punto"):
    print("Generando mapa radial expansivo desde cero... Sé paciente, tardará un rato.")
    from examples.generar_casa_de_campo_punto import generar_por_punto
    generar_por_punto()
    print("✅ Mapa de Casa de Campo por Punto LKP listo.")
else:
    print("⏭️ El mapa de Casa de Campo por Punto LKP YA ESTÁ GENERADO en disco. Saltando generación...")
# Out:
# ⏭️ El mapa de Casa de Campo por Punto LKP YA ESTÁ GENERADO en disco. Saltando generación...

# %% [markdown]
# ## 2. Ejecución de Búsqueda: Estrategia de Polígono (Confinada)
# Ejecutamos los planificadores obligándolos a barrer el área delimitada de la Casa de Campo.
# *Ideal para evaluar tamaños de búsqueda pre-acotados (ej. `medium`, `xlarge`) con presupuestos de batería altos.*

# %%
# Evaluamos los algoritmos con la configuración de Polígono
from examples.evaluar_casa_de_campo import evaluar_casa_de_campo
evaluar_casa_de_campo()

print("Evaluación de Polígono finalizada. Resultados guardados en la carpeta de resultados.")
# Out:
# 2026-06-07 13:50:38,518 - INFO - --- Iniciando Evaluación en la Casa de Campo --- (evaluar_casa_de_campo.py:19)
# 2026-06-07 13:50:38,520 - INFO - Loading datasets for sizes: ['large', 'xlarge'] (evaluator.py:571)
# 2026-06-07 13:50:38,523 - INFO - Attempting to generate dataset for size: 'large' (loading.py:165)
# 2026-06-07 13:50:38,526 - INFO - Loading master dataset from disk for the first time... (loading.py:100)
# 2026-06-07 13:50:39,092 - INFO - Loaded metadata: center=(-3.752500000000001, 40.417500000000004), resolution=20 m/bin (loading.py:111)
# 2026-06-07 13:50:39,642 - INFO - Loaded master probability map with shape (252, 277) (loading.py:127)
# 2026-06-07 13:50:40,223 - INFO - Clipped features to 31539 items for size 'large'. (loading.py:189)
# 2026-06-07 13:50:40,223 - INFO - Final heatmap for size 'large' has a probability sum of 0.9822 (loading.py:227)
# 2026-06-07 13:50:40,250 - INFO - Calculated feature type probabilities: {'brush': 0.00013960855359875987, 'drainage': 0.0013863883032294506, 'field': 0.0013769619918575513, 'linear': 0.19419152182991267, 'road': 0.5756143854333249, 'scrub': 0.00036516578296433847, 'structure': 0.04726897180884014, 'water': 0.003757244752692858, 'woodland': 0.16044904996376647} (lost_person.py:31)
# 2026-06-07 13:50:41,089 - INFO - Attempting to generate dataset for size: 'xlarge' (loading.py:165)
# 2026-06-07 13:50:41,690 - INFO - Clipped features to 33139 items for size 'xlarge'. (loading.py:189)
# 2026-06-07 13:50:41,690 - INFO - Final heatmap for size 'xlarge' has a probability sum of 1.0000 (loading.py:227)
# 2026-06-07 13:50:41,706 - INFO - Calculated feature type probabilities: {'brush': 0.0001453881432196178, 'drainage': 0.0013952736389765412, 'field': 0.0015280562310119985, 'linear': 0.19771154692965417, 'road': 0.5860408374912326, 'scrub': 0.00036516578296433847, 'structure': 0.04847446193291765, 'water': 0.003768929620925921, 'woodland': 0.1605703402290973} (lost_person.py:31)
# 2026-06-07 13:50:42,606 - INFO - All datasets loaded and prepared. (evaluator.py:600)
# 2026-06-07 13:50:42,606 - INFO - --- Evaluando Algoritmos de Cobertura --- (evaluar_casa_de_campo.py:46)
# 2026-06-07 13:50:42,606 - INFO - --- Evaluating Baselines on 'large' dataset --- (evaluator.py:621)
# 2026-06-07 13:50:42,606 - INFO - Running RandomWalk algorithm on 'large' dataset... (evaluator.py:638)
# 2026-06-07 13:54:34,708 - INFO - Running Greedy algorithm on 'large' dataset... (evaluator.py:638)
# 2026-06-07 14:00:00,973 - INFO - Running Spiral algorithm on 'large' dataset... (evaluator.py:638)
# 2026-06-07 14:00:38,040 - INFO - Running Concentric algorithm on 'large' dataset... (evaluator.py:638)
# 2026-06-07 14:01:28,024 - INFO - Running Pizza algorithm on 'large' dataset... (evaluator.py:638)
# 2026-06-07 14:01:58,438 - INFO - --- Evaluating Baselines on 'xlarge' dataset --- (evaluator.py:621)
# 2026-06-07 14:01:58,444 - INFO - Running RandomWalk algorithm on 'xlarge' dataset... (evaluator.py:638)
# 2026-06-07 14:02:45,747 - INFO - Running Greedy algorithm on 'xlarge' dataset... (evaluator.py:638)
# 2026-06-07 14:03:22,270 - INFO - Running Spiral algorithm on 'xlarge' dataset... (evaluator.py:638)
# 2026-06-07 14:11:02,169 - INFO - Running Concentric algorithm on 'xlarge' dataset... (evaluator.py:638)
# 2026-06-07 14:13:48,821 - INFO - Running Pizza algorithm on 'xlarge' dataset... (evaluator.py:638)
# 2026-06-07 14:16:21,137 - INFO - --- Baseline Evaluation Complete --- (evaluator.py:728)
# 2026-06-07 14:16:21,158 - INFO - Results:
#   Dataset   Algorithm Environment Type    Climate Environment Size  n_agents  Budget (m)  Likelihood Score  Time-Discounted Score  Victims Found (%)  Area Covered (km²)  Total Path Length (km)
# 0   large  RandomWalk             flat  temperate            large         3     1500000          0.401578               0.010741               42.0           12.462410             1500.000000
# 1   large      Greedy             flat  temperate            large         3     1500000          0.791540               0.015127               87.0           26.289765             1500.000000
# 2   large      Spiral             flat  temperate            large         3     1500000          0.893804               0.008876              100.0           32.171756              485.442081
# 3   large  Concentric             flat  temperate            large         3     1500000          0.897792               0.009157              100.0           32.453809              491.314838
# 4   large       Pizza             flat  temperate            large         3     1500000          0.897546               0.011568              100.0           32.457158              494.928179
# 5  xlarge  RandomWalk             flat  temperate           xlarge         3     1500000          0.125558               0.000817               46.0           29.179680             1500.000000
# 6  xlarge      Greedy             flat  temperate           xlarge         3     1500000          0.403009               0.001679               79.0           66.489817             1500.000000
# 7  xlarge      Spiral             flat  temperate           xlarge         3     1500000          0.341128               0.000267               96.0           99.418016             1500.000000
# 8  xlarge  Concentric             flat  temperate           xlarge         3     1500000          0.341063               0.000298               98.0           99.266115             1500.000000
# 9  xlarge       Pizza             flat  temperate           xlarge         3     1500000          0.473404               0.000378              100.0           98.805328             1500.000000 (evaluator.py:729)
# 2026-06-07 14:16:21,162 - INFO - --- Generando y Guardando Gráficas Estadísticas --- (evaluar_casa_de_campo.py:50)
# 2026-06-07 14:16:21,338 - INFO - Saved plot to resultados_casa_de_campo/graphs\plot_likelihood_score.png (plot.py:426)
# 2026-06-07 14:16:21,488 - INFO - Saved plot to resultados_casa_de_campo/graphs\plot_time-discounted_score.png (plot.py:426)
# 2026-06-07 14:16:21,665 - INFO - Saved plot to resultados_casa_de_campo/graphs\plot_victims_found_.png (plot.py:426)
# 2026-06-07 14:16:21,826 - INFO - Saved plot to resultados_casa_de_campo/graphs\plot_area_covered_(km²).png (plot.py:426)
# 2026-06-07 14:16:22,006 - INFO - Saved plot to resultados_casa_de_campo/graphs\plot_total_path_length_(km).png (plot.py:426)
# 2026-06-07 14:16:22,006 - INFO - -> Gráficas generadas en: resultados_casa_de_campo/graphs (evaluar_casa_de_campo.py:54)
# 2026-06-07 14:16:22,006 - INFO - --- Generando Visualizaciones de las Rutas --- (evaluar_casa_de_campo.py:57)
# Mapas a evaluar:   0%|          | 0/2 [00:00<?, ?it/s]
# Generando rutas (large):   0%|          | 0/5 [00:00<?, ?it/s]2026-06-07 14:16:22,021 - INFO - Pintando la ruta del algoritmo 'RandomWalk' para tamaño 'large'... (evaluar_casa_de_campo.py:73)
# 2026-06-07 14:16:39,277 - INFO - Saved heatmap plot to resultados_casa_de_campo\paths_plots\RandomWalk_casa_de_campo_ruta_large.pdf (plot.py:121)
# 2026-06-07 14:16:39,277 - INFO - Guardado mapa con ruta: resultados_casa_de_campo\paths_plots\RandomWalk_casa_de_campo_ruta_large.pdf (evaluar_casa_de_campo.py:98)
#
# Generando rutas (large):  20%|██        | 1/5 [00:17<01:09, 17.27s/it]2026-06-07 14:16:39,293 - INFO - Pintando la ruta del algoritmo 'Greedy' para tamaño 'large'... (evaluar_casa_de_campo.py:73)
# 2026-06-07 14:17:09,359 - INFO - Saved heatmap plot to resultados_casa_de_campo\paths_plots\Greedy_casa_de_campo_ruta_large.pdf (plot.py:121)
# 2026-06-07 14:17:09,361 - INFO - Guardado mapa con ruta: resultados_casa_de_campo\paths_plots\Greedy_casa_de_campo_ruta_large.pdf (evaluar_casa_de_campo.py:98)
#
# Generando rutas (large):  40%|████      | 2/5 [00:47<01:14, 24.80s/it]2026-06-07 14:17:09,366 - INFO - Pintando la ruta del algoritmo 'Spiral' para tamaño 'large'... (evaluar_casa_de_campo.py:73)
# 2026-06-07 14:17:10,219 - INFO - Saved heatmap plot to resultados_casa_de_campo\paths_plots\Spiral_casa_de_campo_ruta_large.pdf (plot.py:121)
# 2026-06-07 14:17:10,222 - INFO - Guardado mapa con ruta: resultados_casa_de_campo\paths_plots\Spiral_casa_de_campo_ruta_large.pdf (evaluar_casa_de_campo.py:98)
#
# Generando rutas (large):  60%|██████    | 3/5 [00:48<00:27, 13.87s/it]2026-06-07 14:17:10,228 - INFO - Pintando la ruta del algoritmo 'Concentric' para tamaño 'large'... (evaluar_casa_de_campo.py:73)
# 2026-06-07 14:17:10,983 - INFO - Saved heatmap plot to resultados_casa_de_campo\paths_plots\Concentric_casa_de_campo_ruta_large.pdf (plot.py:121)
# 2026-06-07 14:17:10,985 - INFO - Guardado mapa con ruta: resultados_casa_de_campo\paths_plots\Concentric_casa_de_campo_ruta_large.pdf (evaluar_casa_de_campo.py:98)
#
# Generando rutas (large):  80%|████████  | 4/5 [00:48<00:08,  8.70s/it]2026-06-07 14:17:10,991 - INFO - Pintando la ruta del algoritmo 'Pizza' para tamaño 'large'... (evaluar_casa_de_campo.py:73)
# 2026-06-07 14:17:11,693 - INFO - Saved heatmap plot to resultados_casa_de_campo\paths_plots\Pizza_casa_de_campo_ruta_large.pdf (plot.py:121)
# 2026-06-07 14:17:11,696 - INFO - Guardado mapa con ruta: resultados_casa_de_campo\paths_plots\Pizza_casa_de_campo_ruta_large.pdf (evaluar_casa_de_campo.py:98)
#
# Generando rutas (large): 100%|██████████| 5/5 [00:49<00:00,  5.82s/it]
# Mapas a evaluar:  50%|█████     | 1/2 [00:49<00:49, 49.70s/it]
# Generando rutas (xlarge):   0%|          | 0/5 [00:00<?, ?it/s]2026-06-07 14:17:11,721 - INFO - Pintando la ruta del algoritmo 'RandomWalk' para tamaño 'xlarge'... (evaluar_casa_de_campo.py:73)
# 2026-06-07 14:17:16,989 - INFO - Saved heatmap plot to resultados_casa_de_campo\paths_plots\RandomWalk_casa_de_campo_ruta_xlarge.pdf (plot.py:121)
# 2026-06-07 14:17:16,995 - INFO - Guardado mapa con ruta: resultados_casa_de_campo\paths_plots\RandomWalk_casa_de_campo_ruta_xlarge.pdf (evaluar_casa_de_campo.py:98)
#
# Generando rutas (xlarge):  20%|██        | 1/5 [00:05<00:21,  5.27s/it]2026-06-07 14:17:16,995 - INFO - Pintando la ruta del algoritmo 'Greedy' para tamaño 'xlarge'... (evaluar_casa_de_campo.py:73)
# 2026-06-07 14:17:22,113 - INFO - Saved heatmap plot to resultados_casa_de_campo\paths_plots\Greedy_casa_de_campo_ruta_xlarge.pdf (plot.py:121)
# 2026-06-07 14:17:22,115 - INFO - Guardado mapa con ruta: resultados_casa_de_campo\paths_plots\Greedy_casa_de_campo_ruta_xlarge.pdf (evaluar_casa_de_campo.py:98)
#
# Generando rutas (xlarge):  40%|████      | 2/5 [00:10<00:15,  5.18s/it]2026-06-07 14:17:22,118 - INFO - Pintando la ruta del algoritmo 'Spiral' para tamaño 'xlarge'... (evaluar_casa_de_campo.py:73)
# 2026-06-07 14:17:25,184 - INFO - Saved heatmap plot to resultados_casa_de_campo\paths_plots\Spiral_casa_de_campo_ruta_xlarge.pdf (plot.py:121)
# 2026-06-07 14:17:25,201 - INFO - Guardado mapa con ruta: resultados_casa_de_campo\paths_plots\Spiral_casa_de_campo_ruta_xlarge.pdf (evaluar_casa_de_campo.py:98)
#
# Generando rutas (xlarge):  60%|██████    | 3/5 [00:13<00:08,  4.23s/it]2026-06-07 14:17:25,201 - INFO - Pintando la ruta del algoritmo 'Concentric' para tamaño 'xlarge'... (evaluar_casa_de_campo.py:73)
# 2026-06-07 14:17:29,273 - INFO - Saved heatmap plot to resultados_casa_de_campo\paths_plots\Concentric_casa_de_campo_ruta_xlarge.pdf (plot.py:121)
# 2026-06-07 14:17:29,275 - INFO - Guardado mapa con ruta: resultados_casa_de_campo\paths_plots\Concentric_casa_de_campo_ruta_xlarge.pdf (evaluar_casa_de_campo.py:98)
#
# Generando rutas (xlarge):  80%|████████  | 4/5 [00:17<00:04,  4.17s/it]2026-06-07 14:17:29,279 - INFO - Pintando la ruta del algoritmo 'Pizza' para tamaño 'xlarge'... (evaluar_casa_de_campo.py:73)
# 2026-06-07 14:17:31,019 - INFO - Saved heatmap plot to resultados_casa_de_campo\paths_plots\Pizza_casa_de_campo_ruta_xlarge.pdf (plot.py:121)
# 2026-06-07 14:17:31,023 - INFO - Guardado mapa con ruta: resultados_casa_de_campo\paths_plots\Pizza_casa_de_campo_ruta_xlarge.pdf (evaluar_casa_de_campo.py:98)
#
# Generando rutas (xlarge): 100%|██████████| 5/5 [00:19<00:00,  3.29s/it]
# Mapas a evaluar: 100%|██████████| 2/2 [01:09<00:00, 34.51s/it]
# 2026-06-07 14:17:31,031 - INFO - --- ¡Evaluación Finalizada con Éxito! --- (evaluar_casa_de_campo.py:100)
# Evaluación de Polígono finalizada. Resultados guardados en la carpeta de resultados.

# %% [markdown]
# ## 3. Ejecución de Búsqueda: Estrategia de Punto LKP (Expansión Radial)
# Ejecutamos los algoritmos simulando un escenario donde solo conocemos el Último Punto Conocido (LKP - Last Known Position) y el área de búsqueda se va expandiendo progresivamente.

# %%
# Evaluamos los algoritmos con la configuración de Punto Central
from examples.evaluar_casa_de_campo_punto import evaluar_por_punto
evaluar_por_punto()

print("Evaluación Radial finalizada.")
# Out:
# 2026-06-07 14:17:31,167 - INFO - --- Iniciando Evaluación desde Punto Central (LKP) --- (evaluar_casa_de_campo_punto.py:19)
# 2026-06-07 14:17:31,174 - INFO - Loading datasets for sizes: ['small', 'medium', 'large', 'xlarge'] (evaluator.py:571)
# 2026-06-07 14:17:31,177 - INFO - Attempting to generate dataset for size: 'small' (loading.py:165)
# 2026-06-07 14:17:31,179 - INFO - Loading master dataset from disk for the first time... (loading.py:100)
# 2026-06-07 14:17:39,051 - INFO - Loaded metadata: center=(-3.7337, 40.4187), resolution=20 m/bin (loading.py:111)
# 2026-06-07 14:17:46,771 - INFO - Loaded master probability map with shape (989, 990) (loading.py:127)
# 2026-06-07 14:17:47,253 - INFO - Clipped features to 1172 items for size 'small'. (loading.py:189)
# 2026-06-07 14:17:47,255 - INFO - Final heatmap for size 'small' has a probability sum of 0.0339 (loading.py:227)
# 2026-06-07 14:17:47,255 - INFO - Calculated feature type probabilities: {'brush': 7.689163123325957e-06, 'drainage': 3.0152102168830313e-05, 'linear': 0.009171047475076946, 'road': 0.024673439219994396, 'structure': 0.002814376222459058, 'water': 0.0006263910096375064, 'woodland': 0.025947996415879842} (lost_person.py:31)
# 2026-06-07 14:17:47,655 - INFO - Attempting to generate dataset for size: 'medium' (loading.py:165)
# 2026-06-07 14:17:48,055 - INFO - Clipped features to 15353 items for size 'medium'. (loading.py:189)
# 2026-06-07 14:17:48,055 - INFO - Final heatmap for size 'medium' has a probability sum of 0.2404 (loading.py:227)
# 2026-06-07 14:17:48,055 - INFO - Calculated feature type probabilities: {'brush': 8.59812880418032e-05, 'drainage': 0.000374163255668318, 'field': 0.0001938218285223268, 'linear': 0.05884970940660889, 'road': 0.15648077544969954, 'scrub': 0.00019280321931004657, 'structure': 0.023636889168661638, 'water': 0.002331413139277184, 'woodland': 0.02838220508162352} (lost_person.py:31)
# 2026-06-07 14:17:48,773 - INFO - Attempting to generate dataset for size: 'large' (loading.py:165)
# 2026-06-07 14:17:50,053 - INFO - Clipped features to 50274 items for size 'large'. (loading.py:189)
# 2026-06-07 14:17:50,055 - INFO - Final heatmap for size 'large' has a probability sum of 0.4611 (loading.py:227)
# 2026-06-07 14:17:50,076 - INFO - Calculated feature type probabilities: {'brush': 0.0001287973634454578, 'drainage': 0.0005193438779720276, 'field': 0.000530452303164883, 'linear': 0.11751072838899633, 'road': 0.2985839319040593, 'scrub': 0.00020818656841124533, 'structure': 0.054291353600713556, 'water': 0.002400338538142264, 'woodland': 0.02936166443470295} (lost_person.py:31)
# 2026-06-07 14:17:51,837 - INFO - Attempting to generate dataset for size: 'xlarge' (loading.py:165)
# 2026-06-07 14:17:59,522 - INFO - Clipped features to 388435 items for size 'xlarge'. (loading.py:189)
# 2026-06-07 14:17:59,555 - INFO - Final heatmap for size 'xlarge' has a probability sum of 0.9998 (loading.py:227)
# 2026-06-07 14:17:59,679 - INFO - Calculated feature type probabilities: {'brush': 0.00037228673440130257, 'drainage': 0.0006412109245106912, 'field': 0.008209280726188308, 'linear': 0.2460335297221468, 'road': 0.6015747636278332, 'rock': 2.6468952919990266e-05, 'scrub': 0.0006914932809883242, 'structure': 0.10337338849312175, 'water': 0.002870579376399108, 'woodland': 0.03620699816149042} (lost_person.py:31)
# 2026-06-07 14:18:10,932 - INFO - All datasets loaded and prepared. (evaluator.py:600)
# 2026-06-07 14:18:10,952 - INFO - --- Evaluando Algoritmos (Espiral, Zonas, etc...) --- (evaluar_casa_de_campo_punto.py:43)
# 2026-06-07 14:18:10,956 - INFO - --- Evaluating Baselines on 'small' dataset --- (evaluator.py:621)
# 2026-06-07 14:18:10,960 - INFO - Running RandomWalk algorithm on 'small' dataset... (evaluator.py:638)
# 2026-06-07 14:18:36,014 - INFO - Running Greedy algorithm on 'small' dataset... (evaluator.py:638)
# 2026-06-07 14:19:03,881 - INFO - Running Spiral algorithm on 'small' dataset... (evaluator.py:638)
# 2026-06-07 14:19:04,070 - INFO - Running Concentric algorithm on 'small' dataset... (evaluator.py:638)
# 2026-06-07 14:19:04,341 - INFO - Running Pizza algorithm on 'small' dataset... (evaluator.py:638)
# 2026-06-07 14:19:04,521 - INFO - --- Evaluating Baselines on 'medium' dataset --- (evaluator.py:621)
# 2026-06-07 14:19:04,539 - INFO - Running RandomWalk algorithm on 'medium' dataset... (evaluator.py:638)
# 2026-06-07 14:19:27,848 - INFO - Running Greedy algorithm on 'medium' dataset... (evaluator.py:638)
# 2026-06-07 14:19:42,187 - INFO - Running Spiral algorithm on 'medium' dataset... (evaluator.py:638)
# 2026-06-07 14:19:45,105 - INFO - Running Concentric algorithm on 'medium' dataset... (evaluator.py:638)
# 2026-06-07 14:19:47,903 - INFO - Running Pizza algorithm on 'medium' dataset... (evaluator.py:638)
# 2026-06-07 14:19:50,960 - INFO - --- Evaluating Baselines on 'large' dataset --- (evaluator.py:621)
# 2026-06-07 14:19:50,972 - INFO - Running RandomWalk algorithm on 'large' dataset... (evaluator.py:638)
# 2026-06-07 14:20:12,699 - INFO - Running Greedy algorithm on 'large' dataset... (evaluator.py:638)
# 2026-06-07 14:20:22,982 - INFO - Running Spiral algorithm on 'large' dataset... (evaluator.py:638)
# 2026-06-07 14:20:31,693 - INFO - Running Concentric algorithm on 'large' dataset... (evaluator.py:638)
# 2026-06-07 14:20:38,639 - INFO - Running Pizza algorithm on 'large' dataset... (evaluator.py:638)
# 2026-06-07 14:20:45,199 - INFO - --- Evaluating Baselines on 'xlarge' dataset --- (evaluator.py:621)
# 2026-06-07 14:20:45,207 - INFO - Running RandomWalk algorithm on 'xlarge' dataset... (evaluator.py:638)
# 2026-06-07 14:21:18,323 - INFO - Running Greedy algorithm on 'xlarge' dataset... (evaluator.py:638)
# 2026-06-07 14:21:43,989 - INFO - Running Spiral algorithm on 'xlarge' dataset... (evaluator.py:638)
# 2026-06-07 14:22:14,042 - INFO - Running Concentric algorithm on 'xlarge' dataset... (evaluator.py:638)
# 2026-06-07 14:22:28,626 - INFO - Running Pizza algorithm on 'xlarge' dataset... (evaluator.py:638)
# 2026-06-07 14:22:40,821 - INFO - --- Baseline Evaluation Complete --- (evaluator.py:728)
# 2026-06-07 14:22:40,836 - INFO - Results:
#    Dataset   Algorithm Environment Type    Climate Environment Size  n_agents  Budget (m)  Likelihood Score  Time-Discounted Score  Victims Found (%)  Area Covered (km²)  Total Path Length (km)
# 0    small  RandomWalk             flat  temperate            small         3      250000          0.032991               0.007578               97.0            1.151309              250.000000
# 1    small      Greedy             flat  temperate            small         3      250000          0.033856               0.010548              100.0            1.202824              250.000000
# 2    small      Spiral             flat  temperate            small         3      250000          0.032914               0.006019               98.0            1.133621               17.091880
# 3    small  Concentric             flat  temperate            small         3      250000          0.033615               0.006178               99.0            1.241661               19.039036
# 4    small       Pizza             flat  temperate            small         3      250000          0.033605               0.007240               99.0            1.245003               19.721305
# 5   medium  RandomWalk             flat  temperate           medium         3      250000          0.069176               0.008418               21.0            2.485690              250.000000
# 6   medium      Greedy             flat  temperate           medium         3      250000          0.191983               0.012820               79.0            7.154828              250.000000
# 7   medium      Spiral             flat  temperate           medium         3      250000          0.237960               0.006020              100.0           10.181000              153.618239
# 8   medium  Concentric             flat  temperate           medium         3      250000          0.239255               0.006163              100.0           10.431351              158.315410
# 9   medium       Pizza             flat  temperate           medium         3      250000          0.239493               0.007190              100.0           10.434700              160.345560
# 10   large  RandomWalk             flat  temperate            large         3      250000          0.067144               0.005026                6.0            2.442189              250.000000
# 11   large      Greedy             flat  temperate            large         3      250000          0.238891               0.012801               59.0           11.685952              250.000000
# 12   large      Spiral             flat  temperate            large         3      250000          0.275932               0.006017               51.0           16.575744              250.000000
# 13   large  Concentric             flat  temperate            large         3      250000          0.274814               0.006156               53.0           16.516717              250.000000
# 14   large       Pizza             flat  temperate            large         3      250000          0.324413               0.007187               69.0           16.331086              250.000000
# 15  xlarge  RandomWalk             flat  temperate           xlarge         3      250000          0.073075               0.007147               11.0            2.935111              250.000000
# 16  xlarge      Greedy             flat  temperate           xlarge         3      250000          0.169294               0.013164               18.0            7.041495              250.000000
# 17  xlarge      Spiral             flat  temperate           xlarge         3      250000          0.172211               0.006035               16.0           16.576156              250.000000
# 18  xlarge  Concentric             flat  temperate           xlarge         3      250000          0.172980               0.006223               17.0           16.527952              250.000000
# 19  xlarge       Pizza             flat  temperate           xlarge         3      250000          0.324424               0.007046               39.0           16.331086              250.000000 (evaluator.py:729)
# 2026-06-07 14:22:40,841 - INFO - --- Generando Gráfica Visual --- (evaluar_casa_de_campo_punto.py:46)
# 2026-06-07 14:22:41,167 - INFO - Saved plot to resultados_casa_de_campo_punto/graphs\plot_likelihood_score.png (plot.py:426)
# 2026-06-07 14:22:41,521 - INFO - Saved plot to resultados_casa_de_campo_punto/graphs\plot_time-discounted_score.png (plot.py:426)
# 2026-06-07 14:22:41,754 - INFO - Saved plot to resultados_casa_de_campo_punto/graphs\plot_victims_found_.png (plot.py:426)
# 2026-06-07 14:22:42,088 - INFO - Saved plot to resultados_casa_de_campo_punto/graphs\plot_area_covered_(km²).png (plot.py:426)
# 2026-06-07 14:22:42,428 - INFO - Saved plot to resultados_casa_de_campo_punto/graphs\plot_total_path_length_(km).png (plot.py:426)
# 2026-06-07 14:22:42,428 - INFO - -> Gráficas generadas en: resultados_casa_de_campo_punto/graphs (evaluar_casa_de_campo_punto.py:50)
# 2026-06-07 14:22:42,440 - INFO - --- Generando Visualizaciones de las Rutas sobre el Heatmap --- (evaluar_casa_de_campo_punto.py:52)
# Mapas a evaluar por LKP:   0%|          | 0/4 [00:00<?, ?it/s]
# Generando rutas LKP (small):   0%|          | 0/5 [00:00<?, ?it/s]2026-06-07 14:22:48,615 - INFO - Saved heatmap plot to resultados_casa_de_campo_punto\paths_plots\RandomWalk_punto_small_3drones_250000m.pdf (plot.py:121)
#
# Generando rutas LKP (small):  20%|██        | 1/5 [00:06<00:24,  6.16s/it]2026-06-07 14:22:54,519 - INFO - Saved heatmap plot to resultados_casa_de_campo_punto\paths_plots\Greedy_punto_small_3drones_250000m.pdf (plot.py:121)
#
# Generando rutas LKP (small):  40%|████      | 2/5 [00:12<00:18,  6.01s/it]2026-06-07 14:22:54,888 - INFO - Saved heatmap plot to resultados_casa_de_campo_punto\paths_plots\Spiral_punto_small_3drones_250000m.pdf (plot.py:121)
#
# Generando rutas LKP (small):  60%|██████    | 3/5 [00:12<00:06,  3.43s/it]2026-06-07 14:22:55,221 - INFO - Saved heatmap plot to resultados_casa_de_campo_punto\paths_plots\Concentric_punto_small_3drones_250000m.pdf (plot.py:121)
#
# Generando rutas LKP (small):  80%|████████  | 4/5 [00:12<00:02,  2.21s/it]2026-06-07 14:22:55,569 - INFO - Saved heatmap plot to resultados_casa_de_campo_punto\paths_plots\Pizza_punto_small_3drones_250000m.pdf (plot.py:121)
#
# Generando rutas LKP (small): 100%|██████████| 5/5 [00:13<00:00,  1.54s/it]
# Mapas a evaluar por LKP:  25%|██▌       | 1/4 [00:13<00:39, 13.13s/it]
# Generando rutas LKP (medium):   0%|          | 0/5 [00:00<?, ?it/s]2026-06-07 14:23:01,721 - INFO - Saved heatmap plot to resultados_casa_de_campo_punto\paths_plots\RandomWalk_punto_medium_3drones_250000m.pdf (plot.py:121)
#
# Generando rutas LKP (medium):  20%|██        | 1/5 [00:06<00:24,  6.13s/it]2026-06-07 14:23:07,886 - INFO - Saved heatmap plot to resultados_casa_de_campo_punto\paths_plots\Greedy_punto_medium_3drones_250000m.pdf (plot.py:121)
#
# Generando rutas LKP (medium):  40%|████      | 2/5 [00:12<00:18,  6.15s/it]2026-06-07 14:23:08,294 - INFO - Saved heatmap plot to resultados_casa_de_campo_punto\paths_plots\Spiral_punto_medium_3drones_250000m.pdf (plot.py:121)
#
# Generando rutas LKP (medium):  60%|██████    | 3/5 [00:12<00:07,  3.53s/it]2026-06-07 14:23:08,799 - INFO - Saved heatmap plot to resultados_casa_de_campo_punto\paths_plots\Concentric_punto_medium_3drones_250000m.pdf (plot.py:121)
#
# Generando rutas LKP (medium):  80%|████████  | 4/5 [00:13<00:02,  2.34s/it]2026-06-07 14:23:09,202 - INFO - Saved heatmap plot to resultados_casa_de_campo_punto\paths_plots\Pizza_punto_medium_3drones_250000m.pdf (plot.py:121)
#
# Generando rutas LKP (medium): 100%|██████████| 5/5 [00:13<00:00,  1.64s/it]
# Mapas a evaluar por LKP:  50%|█████     | 2/4 [00:26<00:26, 13.43s/it]
# Generando rutas LKP (large):   0%|          | 0/5 [00:00<?, ?it/s]2026-06-07 14:23:15,668 - INFO - Saved heatmap plot to resultados_casa_de_campo_punto\paths_plots\RandomWalk_punto_large_3drones_250000m.pdf (plot.py:121)
#
# Generando rutas LKP (large):  20%|██        | 1/5 [00:06<00:25,  6.45s/it]2026-06-07 14:23:21,820 - INFO - Saved heatmap plot to resultados_casa_de_campo_punto\paths_plots\Greedy_punto_large_3drones_250000m.pdf (plot.py:121)
#
# Generando rutas LKP (large):  40%|████      | 2/5 [00:12<00:18,  6.27s/it]2026-06-07 14:23:23,017 - INFO - Saved heatmap plot to resultados_casa_de_campo_punto\paths_plots\Spiral_punto_large_3drones_250000m.pdf (plot.py:121)
#
# Generando rutas LKP (large):  60%|██████    | 3/5 [00:13<00:07,  3.96s/it]2026-06-07 14:23:23,871 - INFO - Saved heatmap plot to resultados_casa_de_campo_punto\paths_plots\Concentric_punto_large_3drones_250000m.pdf (plot.py:121)
#
# Generando rutas LKP (large):  80%|████████  | 4/5 [00:14<00:02,  2.73s/it]2026-06-07 14:23:24,388 - INFO - Saved heatmap plot to resultados_casa_de_campo_punto\paths_plots\Pizza_punto_large_3drones_250000m.pdf (plot.py:121)
#
# Generando rutas LKP (large): 100%|██████████| 5/5 [00:15<00:00,  1.93s/it]
# Mapas a evaluar por LKP:  75%|███████▌  | 3/4 [00:41<00:14, 14.23s/it]
# Generando rutas LKP (xlarge):   0%|          | 0/5 [00:00<?, ?it/s]2026-06-07 14:23:31,060 - INFO - Saved heatmap plot to resultados_casa_de_campo_punto\paths_plots\RandomWalk_punto_xlarge_3drones_250000m.pdf (plot.py:121)
#
# Generando rutas LKP (xlarge):  20%|██        | 1/5 [00:06<00:26,  6.66s/it]2026-06-07 14:23:37,644 - INFO - Saved heatmap plot to resultados_casa_de_campo_punto\paths_plots\Greedy_punto_xlarge_3drones_250000m.pdf (plot.py:121)
#
# Generando rutas LKP (xlarge):  40%|████      | 2/5 [00:13<00:19,  6.61s/it]2026-06-07 14:23:42,271 - INFO - Saved heatmap plot to resultados_casa_de_campo_punto\paths_plots\Spiral_punto_xlarge_3drones_250000m.pdf (plot.py:121)
#
# Generando rutas LKP (xlarge):  60%|██████    | 3/5 [00:17<00:11,  5.71s/it]2026-06-07 14:23:46,947 - INFO - Saved heatmap plot to resultados_casa_de_campo_punto\paths_plots\Concentric_punto_xlarge_3drones_250000m.pdf (plot.py:121)
#
# Generando rutas LKP (xlarge):  80%|████████  | 4/5 [00:22<00:05,  5.30s/it]2026-06-07 14:23:49,206 - INFO - Saved heatmap plot to resultados_casa_de_campo_punto\paths_plots\Pizza_punto_xlarge_3drones_250000m.pdf (plot.py:121)
#
# Generando rutas LKP (xlarge): 100%|██████████| 5/5 [00:24<00:00,  4.20s/it]
# Mapas a evaluar por LKP: 100%|██████████| 4/4 [01:06<00:00, 16.69s/it]
# 2026-06-07 14:23:49,224 - INFO - --- Evaluación finalizada. Revisa los PDFs en 'resultados_casa_de_campo_punto/paths_plots' --- (evaluar_casa_de_campo_punto.py:88)
# Evaluación Radial finalizada.

# %% [markdown]
# ## 4. Visualización Rápida de Resultados
# Cargamos uno de los PDFs generados para ver las trayectorias directamente aquí dentro del Notebook sin tener que ir buscando los archivos manualmente por las carpetas.

# %%
import os
from IPython.display import IFrame, display

# Puedes elegir qué visualización cargar cambiando estas rutas
ruta_poligono = "resultados_casa_de_campo/paths_plots/Greedy_casa_de_campo_ruta_medium.pdf"
ruta_punto = "resultados_casa_de_campo_punto/paths_plots/Greedy_punto_medium_3drones_250000m.pdf"

print("Visualización de Ruta: Estrategia de Polígono")
if os.path.exists(ruta_poligono):
    display(IFrame(ruta_poligono, width=900, height=500))
else:
    print(f"No se encontró: {ruta_poligono}")

print("\nVisualización de Ruta: Estrategia de Punto LKP")
if os.path.exists(ruta_punto):
    display(IFrame(ruta_punto, width=900, height=500))
else:
    print(f"No se encontró: {ruta_punto}")
# Out:
# Visualización de Ruta: Estrategia de Polígono
#         <iframe
#             width="900"
#             height="500"
#             src="resultados_casa_de_campo/paths_plots/Greedy_casa_de_campo_ruta_medium.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Visualización de Ruta: Estrategia de Punto LKP
#         <iframe
#             width="900"
#             height="500"
#             src="resultados_casa_de_campo_punto/paths_plots/Greedy_punto_medium_3drones_250000m.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 5. Resultados Estadísticos (Casa de Campo)
# Como hemos evaluado el rendimiento en los pasos anteriores, los algoritmos ya han generado sus propias gráficas comparativas con las estadísticas de éxito dentro de tu carpeta `resultados_casa_de_campo/graphs`. Las extraemos y mostramos directamente aquí para tus pruebas locales.

# %%
import os
from IPython.display import Image, display

# Gráficas del Polígono
ruta_victimas_poly = "resultados_casa_de_campo/graphs/plot_victims_found_.png"
ruta_area_poly = "resultados_casa_de_campo/graphs/plot_area_covered_(km²).png"

# Gráficas del Punto LKP
ruta_victimas_punto = "resultados_casa_de_campo_punto/graphs/plot_victims_found_.png"
ruta_area_punto = "resultados_casa_de_campo_punto/graphs/plot_area_covered_(km²).png"

print("============== RESULTADOS ESTRATEGIA POLÍGONO ==============")
if os.path.exists(ruta_victimas_poly):
    display(Image(filename=ruta_victimas_poly))
if os.path.exists(ruta_area_poly):
    display(Image(filename=ruta_area_poly))

print("\n============== RESULTADOS ESTRATEGIA PUNTO LKP ==============")
if os.path.exists(ruta_victimas_punto):
    display(Image(filename=ruta_victimas_punto))
if os.path.exists(ruta_area_punto):
    display(Image(filename=ruta_area_punto))
# Out:
# ============== RESULTADOS ESTRATEGIA POLÍGONO ==============
# ============== RESULTADOS ESTRATEGIA PUNTO LKP ==============
